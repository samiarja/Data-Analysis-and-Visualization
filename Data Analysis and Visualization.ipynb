# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train=pd.read_csv('D:/pythonWD/algorithm_practice/Titanic_data/train.csv')
df_test=pd.read_csv('D:/pythonWD/algorithm_practice/Titanic_data/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                      35
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
df_train.iloc[[2, 1, 0]]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 1            2         1       1
# 0            1         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 0                            Braund, Mr. Owen Harris    male  22.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 0      0         A/5 21171   7.2500   NaN        S

# %%
df_train[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df_train[3:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#    Ticket   Fare Cabin Embarked
# 3  113803  53.10  C123        S
# 4  373450   8.05   NaN        S

# %%
df_train['Name'].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df_train['Survived'].head(3)
# Out:
# 0    0
# 1    1
# 2    1
# Name: Survived, dtype: int64

# %%
df_train.Name.head(3)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# Name: Name, dtype: object

# %%
df_train.columns=[col.replace(' ', '_').lower() for col in df_train.columns]
print(df_train.columns)
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df_train[['name', 'sex']][45:50]
# Out:
#                                              name     sex
# 45                       Rogers, Mr. William John    male
# 46                              Lennon, Mr. Denis    male
# 47                      O'Driscoll, Miss. Bridget  female
# 48                            Samaan, Mr. Youssef    male
# 49  Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female

# %%
df_train.sex.iloc[46]
# Out:
# 'male'

# %%
df_train.sex.iloc[[4]]
# Out:
# 4    male
# Name: sex, dtype: object

# %%
(df_train.name == 'passengerid').head(11)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: name, dtype: bool

# %%
df_train[df_train.name == 'passengerid']
# Out:
# Empty DataFrame
# Columns: [passengerid, survived, pclass, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked]
# Index: []

# %%
df_train[df_train['name'].str.split().apply(lambda x: len(x) == 3)].head(10)
# Out:
#     passengerid  survived  pclass                         name     sex   age  \
# 2             3         1       3       Heikkinen, Miss. Laina  female  26.0
# 5             6         0       3             Moran, Mr. James    male   NaN
# 11           12         1       1     Bonnell, Miss. Elizabeth  female  58.0
# 16           17         0       3         Rice, Master. Eugene    male   2.0
# 19           20         1       3      Masselmani, Mrs. Fatima  female   NaN
# 21           22         1       2        Beesley, Mr. Lawrence    male  34.0
# 29           30         0       3          Todoroff, Mr. Lalio    male   NaN
# 36           37         1       3             Mamee, Mr. Hanna    male   NaN
# 39           40         1       3  Nicola-Yarred, Miss. Jamila  female  14.0
# 42           43         0       3          Kraeff, Mr. Theodor    male   NaN
#
#     sibsp  parch            ticket     fare cabin embarked
# 2       0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df_train[df_train.sex.isin(['male'])].head(10)
# Out:
#     passengerid  survived  pclass                            name   sex   age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 5             6         0       3                Moran, Mr. James  male   NaN
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7             8         0       3  Palsson, Master. Gosta Leonard  male   2.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
# 16           17         0       3            Rice, Master. Eugene  male   2.0
# 17           18         1       2    Williams, Mr. Charles Eugene  male   NaN
# 20           21         0       2            Fynney, Mr. Joseph J  male  35.0
#
#     sibsp  parch     ticket     fare cabin embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# ...

# %%
df_train['sex'].value_counts().head(10).plot.bar()

# %%
(df_train['age'].value_counts().head(10)/ len(df_train)).plot.bar()

# %%
df_train['age'].value_counts().sort_index().plot.bar()

# %%
df_train['age'].value_counts().sort_index().plot.line()

# %%
df_train['age'].value_counts().sort_index().plot.area()

# %%
df_train[df_train['age']< 70]['age'].plot.hist()

# %%
df_train[df_train['age']< 40]
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 34            35         0       1
# 37            38         0       3
# 38            39         0       3
# 39            40         1       3
# ...

# %%
df_train_legendary=df_train.groupby(['survived', 'sex']).mean()[['age', 'passengerid']]
df_train_legendary.plot.bar(stacked=True)

# %%
df_train['pclass'].value_counts().sort_index().plot.bar()

# %%
df_train['sex'].value_counts().sort_index().plot.bar(figsize=(12,6))

# %%
df_train['sex'].value_counts().sort_index().plot.bar(figsize=(12,12),
                                                    color='mediumvioletred')

# %%
df_train['sex'].value_counts().sort_index().plot.bar(figsize=(12,12),
                                        color='mediumvioletred',
                                        fontsize=16,
                                        title='Passengers Gender')

# %%
import matplotlib.pyplot as plt

# %%
ax=df_train['sex'].value_counts().sort_index().plot.bar(figsize=(12,12),
                                                       color='mediumvioletred',
                                                       fontsize=16,
                                                       )
ax.set_title("Passenger Gender", fontsize=20)
# Out:
# Text(0.5,1,'Passenger Gender')

# %%
import seaborn as sns

# %%
ax=df_train['sex'].value_counts().sort_index().plot.bar(figsize=(12,12),
                                                     color='mediumvioletred',
                                                     fontsize=16)
ax.set_title("Passenger Gender", fontsize=20)
sns.despine(bottom=True, left=True)

# %%
fig, axarr=plt.subplots(2,1,figsize=(12,8))
df_train['sex'].value_counts().sort_index().plot.bar(ax=axarr[0])
df_train['pclass'].value_counts().head(20).plot.bar(ax=axarr[1])

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

df_train['sex'].value_counts().sort_index().plot.bar(
    ax=axarr[0][0], fontsize=12, color='mediumvioletred'
)
axarr[0][0].set_title("gender", fontsize=18)

df_train['pclass'].value_counts().head(20).plot.bar(
    ax=axarr[1][0], fontsize=12, color='mediumvioletred'
)
axarr[1][0].set_title("Class", fontsize=18)

df_train['passengerid'].value_counts().head(20).plot.bar(
    ax=axarr[1][1], fontsize=12, color='mediumvioletred'
)
axarr[1][1].set_title("ID", fontsize=18)

df_train['fare'].value_counts().plot.hist(
    ax=axarr[0][1], fontsize=12, color='mediumvioletred'
)
axarr[0][1].set_title("Prices", fontsize=18)

plt.subplots_adjust(hspace=.3)
sns.despine()
